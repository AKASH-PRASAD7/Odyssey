# %% [markdown]
# ## Intro to Numpy

# %%
import numpy as np
import time

# %%
arr = np.array([1,2,3,4,5,6])
print("Array:", arr)

# 2D array
arr_2d = np.array([[1,2,3], [4,5,6]])
print("2D Array:\n", arr_2d)
# Out:
# Array: [1 2 3 4 5 6]
# 2D Array:
#  [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## List vs Numpy Array
# - Lists are general-purpose containers that can hold different types of data, while NumPy arrays are specifically designed for numerical computations and are more efficient for large datasets.

# %%
import time
list = [1,2,3,4]
arr = np.array(list)

print("Python list multiplication:", list * 2) 
print("NumPy array multiplication:", arr * 2)

start = time.time()

l1 = [x*2 for x in range(1000000)]
print("\nTime taken for list comprehension:", time.time() - start)

start = time.time()
a1 = np.arange(1000000) * 2
print("\nTime taken for NumPy array operation:", time.time() - start)
# Out:
# Python list multiplication: [1, 2, 3, 4, 1, 2, 3, 4]
# NumPy array multiplication: [2 4 6 8]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       3
#       4 print("Python list multiplication:", list * 2)
#       5 print("NumPy array multiplication:", arr * 2)
#       6
# ----> 7 start = time.time()
#       8
#       9 l1 = [x*2 for x in range(1000000)]
#      10 print("\nTime taken for list comprehension:", time.time() - start)
#
# NameError: name 'time' is not defined
